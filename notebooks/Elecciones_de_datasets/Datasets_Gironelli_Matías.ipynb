# %% [markdown]
# # 1. Detección de fraude en transacciones con tarjetas de crédito

# %%
import numpy as np
import pandas as pd

# %%
#Cargar el Dataset
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-87a41061-a375-44e5-89d6-3bb9aa02de29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87a41061-a375-44e5-89d6-3bb9aa02de29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Leer el Dataset
creditcard = pd.read_csv('fraud_cut.csv')

#Mostrar el Dataset
creditcard
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0       6/21/2020 12:14  2.291160e+15
# 1                1       6/21/2020 12:14  3.573030e+15
# 2                2       6/21/2020 12:14  3.598220e+15
# 3                3       6/21/2020 12:15  3.591920e+15
# 4                4       6/21/2020 12:15  3.526830e+15
# ...            ...                   ...           ...
# 149996      149996        8/12/2020 7:46  3.409540e+14
# 149997      149997        8/12/2020 7:49  3.788580e+14
# 149998      149998        8/12/2020 7:49  3.563840e+15
# 149999      149999        8/12/2020 7:51  5.020130e+11
# 150000      150000        8/12/2020 7:52  4.981130e+12
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %% [markdown]
# .
#
# ---

# %% [markdown]
# # 2. Predicción de criptomoneda. Precio: BTC y ETH

# %%
#Cargar el Dataset
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f8daebab-8764-4553-801f-8ec3a29c276e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8daebab-8764-4553-801f-8ec3a29c276e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Leer el Dataset
btc = pd.read_csv('coin_Bitcoin.csv')

#Mostrar el Dataset
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
#Leer el Dataset
eth = pd.read_csv('coin_Ethereum.csv')
#Mostrar el Dataset
eth
# Out:
#        SNo      Name Symbol                 Date         High          Low  \
# 0        1  Ethereum    ETH  2015-08-08 23:59:59     2.798810     0.714725
# 1        2  Ethereum    ETH  2015-08-09 23:59:59     0.879810     0.629191
# 2        3  Ethereum    ETH  2015-08-10 23:59:59     0.729854     0.636546
# 3        4  Ethereum    ETH  2015-08-11 23:59:59     1.131410     0.663235
# 4        5  Ethereum    ETH  2015-08-12 23:59:59     1.289940     0.883608
# ...    ...       ...    ...                  ...          ...          ...
# 2155  2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496  2021.824808
# 2156  2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155  2117.590013
# 2157  2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857  2190.837703
# 2158  2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836  2163.041394
# 2159  2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874  2197.919385
#
#              Open        Close        Volume     Marketcap
# ...

# %% [markdown]
# .
#
#
# ---

# %% [markdown]
# # 3. RoboAdvisor para la formación de una cartera de acciones según el perfil del usuario

# %%
#Cargar el Dataset
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bd15ae09-3e19-4bb5-ab1a-2bc92e71358b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd15ae09-3e19-4bb5-ab1a-2bc92e71358b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Leer el Dataset
acciones = pd.read_csv('Acciones.csv')

#Mostrar el Dataset
acciones
# Out:
#            Fecha    AL30    ALUA    AUSO     BMA    BYMA    CEPU   CGPA2  \
# 0      2/12/2022  7530.0  164.25  285.00  457.30  204.00  178.75  160.00
# 1      1/12/2022  7630.0  168.00  270.00  463.25  205.75  184.40  157.75
# 2     30/11/2022  7470.5  166.50  253.50  466.30  205.00  180.50  155.50
# 3     29/11/2022  7200.0  164.00  247.00  446.50  194.75  183.00  154.00
# 4     28/11/2022  7072.0  157.50  239.50  445.00  190.00  177.00  155.50
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# 2175   28/2/2014     NaN    3.95    1.89   23.50     NaN     NaN    1.69
# 2176   27/2/2014     NaN    4.03     NaN   23.25     NaN     NaN    1.67
# 2177   26/2/2014     NaN    4.11    1.89   23.60     NaN     NaN     NaN
# 2178   25/2/2014     NaN    4.15     NaN   24.00     NaN     NaN     NaN
# 2179   24/2/2014     NaN    4.16    1.95   23.85     NaN     NaN     NaN
#
#         COME    CVH  ...    SUPV   TC23   TECO2   TGNO4   TGSU2    TRAN  \
# ...

# %% [markdown]
# # 4.Diseño de un reactor químico

# %%
#Cargar el Dataset
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-912c57e7-2a4c-4a32-be74-bbf3c60f2c2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-912c57e7-2a4c-4a32-be74-bbf3c60f2c2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Leer el Dataset
reactor = pd.read_csv('reactor.csv')

#Mostrar el Dataset
reactor
# Out:
#       D         L          M  feed_temp   n_reactor  Pump Operating Cost  \
# 0   NaN  2.647877  18.287788   1.000457  349.429909             2.172580
# 1   NaN  0.780947   5.470245   2.382243  360.762097             5.305146
# 2   NaN  2.660368  17.445268   1.817809  418.524092             1.218827
# 3   NaN  4.105188  11.015315   3.234759  329.996433             2.582831
# 4   NaN  4.854281  24.238278   2.253697  396.228714             8.002349
# ..   ..       ...        ...        ...         ...                  ...
# 149 NaN       NaN        NaN        NaN         NaN                  NaN
# 150 NaN       NaN        NaN        NaN         NaN                  NaN
# 151 NaN       NaN        NaN        NaN         NaN                  NaN
# 152 NaN       NaN        NaN        NaN         NaN                  NaN
# 153 NaN       NaN        NaN        NaN         NaN                  NaN
#
#      Preheat Operating Cost  PTSA Reactant Cost  IPA Reactant Cost  \
# ...

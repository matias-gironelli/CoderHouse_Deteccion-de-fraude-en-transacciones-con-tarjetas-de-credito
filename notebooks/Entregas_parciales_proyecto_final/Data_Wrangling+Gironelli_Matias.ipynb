# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Como mi dataset para el proyecto final es generado por una herramienta ya que son datos de transacciones de tarjetas de créditos. El mismo un dataset limpio, sin valores duplicados ni inválidos, ordenas y listos para usar; como se comprobará más adelante.
#
# Mis otros datasets (no elegidos para el proyecto final) también son de esta manera ya que son datos financieros extraídos de paginas de finanzas listas para su análisis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar el Dataset
from google.colab import drive
import os
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
#Leer el Dataset
# %cd '/content/gdrive/MyDrive/CoderHouse/Data_Science'
creditcard1 = pd.read_csv('fraud.csv')
# Out:
# /content/gdrive/MyDrive/CoderHouse/Data_Science

# %%
#Mostrar el Dataset
creditcard1
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0         1/1/2019 0:00  2.703190e+15
# 1                1         1/1/2019 0:00  6.304230e+11
# 2                2         1/1/2019 0:00  3.885950e+13
# 3                3         1/1/2019 0:01  3.534090e+15
# 4                4         1/1/2019 0:03  3.755340e+14
# ...            ...                   ...           ...
# 199996      199996         3/1/2020 0:02  3.585740e+15
# 199997      199997         3/1/2020 0:06  3.512370e+15
# 199998      199998         3/1/2020 0:07  4.229730e+15
# 199999      199999         3/1/2020 0:07  4.390970e+18
# 200000      200000         3/1/2020 0:08  4.158010e+12
#
#                                   merchant       category     amt      first  \
# 0               fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1          fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# ...

# %%
#Leer el Dataset
# %cd '/content/gdrive/MyDrive/CoderHouse/Data_Science'
creditcard2 = pd.read_csv('fraudTest.csv')
# Out:
# /content/gdrive/MyDrive/CoderHouse/Data_Science

# %%
#Mostrar el Dataset
creditcard2
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0       6/21/2020 12:14  2.291160e+15
# 1                1       6/21/2020 12:14  3.573030e+15
# 2                2       6/21/2020 12:14  3.598220e+15
# 3                3       6/21/2020 12:15  3.591920e+15
# 4                4       6/21/2020 12:15  3.526830e+15
# ...            ...                   ...           ...
# 99996        99996       7/26/2020 12:57  4.482430e+15
# 99997        99997       7/26/2020 12:57  5.580560e+15
# 99998        99998       7/26/2020 12:58  4.294040e+15
# 99999        99999       7/26/2020 12:58  3.577580e+15
# 100000      100000       7/26/2020 12:59  6.511350e+15
#
#                                     merchant        category    amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care   2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care  29.84   Joanne
# ...

# %%
creditcard = pd.concat([creditcard1, creditcard2], axis=0)

# %% [markdown]
# A modo solo de ejercicio para concatenar, uní los datasets de test y training. Luego comprobé que no tuvieran valores no validos ni repetidos.
#
# Con axix=0 indicamos que queremos unirlo por columnas los datasets

# %%
creditcard.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  300002.000000  3.000020e+05  300002.000000  300002.000000
# mean    83333.277778  4.175180e+17      70.510618   48803.641312
# std     55277.406476  1.308891e+18     147.230971   26858.483643
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%     37500.000000  1.800360e+14       9.690000   26237.000000
# 50%     75000.000000  3.519610e+15      47.740000   48174.000000
# 75%    124999.750000  4.642260e+15      83.390000   72011.000000
# max    200000.000000  4.992350e+18   13149.150000   99783.000000
#
#                  lat           long      city_pop     unix_time  \
# count  300002.000000  300002.000000  3.000020e+05  3.000020e+05
# mean       38.539231     -90.208155  8.882757e+04  1.353583e+09
# std         5.076702      13.724701  3.017880e+05  1.904215e+07
# min        20.027100    -165.672300  2.300000e+01  1.325376e+09
# ...

# %%
creditcard.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
creditcard.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 99996     False
# 99997     False
# 99998     False
# 99999     False
# 100000    False
# Length: 300002, dtype: bool

# %%
creditcard.drop_duplicates(inplace=True)

# %%
creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300002 entries, 0 to 100000
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             300002 non-null  int64
#  1   trans_date_trans_time  300002 non-null  object
#  2   cc_num                 300002 non-null  float64
#  3   merchant               300002 non-null  object
#  4   category               300002 non-null  object
#  5   amt                    300002 non-null  float64
#  6   first                  300002 non-null  object
#  7   last                   300002 non-null  object
#  8   gender                 300002 non-null  object
#  9   street                 300002 non-null  object
#  10  city                   300002 non-null  object
#  11  state                  300002 non-null  object
#  12  zip                    300002 non-null  int64
#  13  lat                    300002 non-null  float64
# ...

# %% [markdown]
# No faltan datos en el conjunto y también se eliminaron cualquier observación duplicada.
